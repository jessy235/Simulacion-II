# %% [markdown]
# <a href="https://colab.research.google.com/github/jessy235/Simulacion-II/blob/main/Metodo_de_montecarlo_a)_acierto_y_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# %%
def g(X):
  return np.sqrt(np.arctan(x))

# %%
aciertos=0
N=1000

# %%
for i in range(10):
 x=rd.random()
 y=rd.random()
 plt.scatter(x,y)

# %%
X=np.linspace(0,1,100)
Y=g(X)
plt.plot(X,Y)
for i in range(N):
 x=rd.random()
 y=rd.random()
 if y<=g(x):
  plt.scatter(x,y,color="pink")
  aciertos+=1
 else:
  plt.scatter(x,y,color="purple")

# %%
aciertos
# Out:
# 637

# %%
I=aciertos/N

# %%
print(I)
# Out:
# 0.637
